# %% [markdown]
# <a href="https://colab.research.google.com/github/CADisHARD/C-Code-Copy/blob/master/EECE_564_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hello!
# Out:
#   File "/tmp/ipykernel_933/3864925399.py", line 1
#     Hello!
#          ^
# SyntaxError: invalid syntax
